# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Spark DataFrames").getOrCreate()
data = [(1,"John"),(2,"Mary"),(3,"Bob"),(4,"Sue")]
df = spark.createDataFrame(data,["id","name"])
df.show()
